# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-yusupov/titanic-prediction/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("./data.csv")

columns = ['Passengerid', 'Age', 'Fare', 'Sex', 'sibsp', 'Embarked', 'zero.17',
       'zero.18', '2urvived']

data = data[['Age', 'Fare', 'Sex', '2urvived']]

data.dropna(inplace=True)

# %% [markdown]
# # Data Preprocessing.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data[['Age', 'Fare']] = scaler.fit_transform(data[['Age', 'Fare']])

data
# Out:
#            Age      Fare  Sex  2urvived
# 0     0.273456  0.014151    0         0
# 1     0.473882  0.139136    1         1
# 2     0.323563  0.015469    1         1
# 3     0.436302  0.103644    1         1
# 4     0.436302  0.015713    0         0
# ...        ...       ...  ...       ...
# 1304  0.348616  0.015713    0         0
# 1305  0.486409  0.212559    1         0
# 1306  0.480145  0.014151    0         0
# 1307  0.348616  0.015713    0         0
# 1308  0.348616  0.043640    0         0
#
# [1309 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

X = data.drop('2urvived', axis=1)
Y = data['2urvived']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # Random Forest Classifier model training

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score

model_rf = RandomForestClassifier(n_estimators=100, random_state=42)
model_rf.fit(X_train, Y_train)

Y_pred = model_rf.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred)

print("Accuracy: " + str(accuracy))
print("Recall: " + str(recall))
print("Precision: " + str(precision))
# Out:
# Accuracy: 0.7366412213740458
# Recall: 0.4931506849315068
# Precision: 0.5294117647058824

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression()
model_lr.fit(X_train, Y_train)

Y_pred = model_lr.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred)

print("Accuracy: " + str(accuracy))
print("Recall: " + str(recall))
print("Precision: " + str(precision))
# Out:
# Accuracy: 0.7595419847328244
# Recall: 0.2054794520547945
# Precision: 0.75
